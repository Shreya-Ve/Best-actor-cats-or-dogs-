# %%
import pandas as pd

# %%
data=pd.read_csv("catsdogs.csv")

# %%
data
# Out:
#     Year                                  name_cat  net_cat  \
# 0   1961                    Breakfast at Tiffany's     70.0
# 1   1961                     The Shadow of the cat      1.5
# 2   2001                               Cats & Dogs    200.0
# 3   1965                            That Darn Cat!     20.0
# 4   1972                             Fritz the Cat      1.0
# ..   ...                                       ...      ...
# 56  1977                               The Uncanny      8.0
# 57  1979                                     Alien      6.0
# 58  1996  Homeward Bound II: Lost in San Francisco      3.0
# 59  2002                           Stuart Little 2      4.5
# 60  2011                             Puss in Boots      9.0
#
#                                          name_dog  net_dog
# 0                  One Hundred and One Dalmatians    302.1
# 1                                Greyfriars Bobby     14.0
# 2                                     dog eat dog      9.1
# ...

# %%
import matplotlib.pyplot as plt

# %%
data=data.drop_duplicates(subset=['Year'])

# %%
data=data.sort_values("Year")

# %%
data
# Out:
#     Year                                  name_cat  net_cat  \
# 40  1903                           The Sick Kitten     18.0
# 36  1934                             The Black Cat     80.0
# 39  1940                                 Pinocchio     12.0
# 21  1942                                Cat People     95.0
# 6   1944                 The Private Life of a Cat      2.0
# 45  1950                                Cinderella      5.0
# 54  1951                       Alice in Wonderland      7.0
# 23  1955                        Lady and the Tramp     10.0
# 10  1958                     Bell, Book and Candle     40.0
# 12  1960                             La Dolce Vita     15.0
# 0   1961                    Breakfast at Tiffany's     70.0
# 51  1962                               Gay Purr-ee     90.0
# 37  1963                    The Incredible Journey     40.0
# 13  1964              The Three Lives of Thomasina      5.5
# 3   1965                            That Darn Cat!     20.0
# ...

# %%
data.plot(x='Year', y=['net_cat', 'net_dog'])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
data["net_cat"].mean()
# Out:
# 36.22727272727273

# %%
data["net_dog"].mean()
# Out:
# 41.43181818181818
